# %%
import pandas as pd
planes_df = pd.read_csv('../data/planes.csv')

# %%
planes_df
# Out:
#      tailnum    year                     type                   manufacturer  \
# 0     N10156  2004.0  Fixed wing multi engine                        EMBRAER
# 1     N102UW  1998.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 2     N103US  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 3     N104UW  1999.0  Fixed wing multi engine               AIRBUS INDUSTRIE
# 4     N10575  2002.0  Fixed wing multi engine                        EMBRAER
# ...      ...     ...                      ...                            ...
# 3317  N997AT  2002.0  Fixed wing multi engine                         BOEING
# 3318  N997DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3319  N998AT  2002.0  Fixed wing multi engine                         BOEING
# 3320  N998DL  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3321  N999DN  1992.0  Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
# ...

# %%
#subset variables (select which variables/columns we want)
#this outputs a series
#a series can only hold one variable
planes_df['year'].head()
# Out:
# 0    2004.0
# 1    1998.0
# 2    1999.0
# 3    1999.0
# 4    2002.0
# Name: year, dtype: float64

# %%
type(planes_df['year'])
# Out:
# pandas.core.series.Series

# %%
#this syntax outputs a data frame
planes_df[['year']].head()
# Out:
#      year
# 0  2004.0
# 1  1998.0
# 2  1999.0
# 3  1999.0
# 4  2002.0

# %%
type(planes_df[['year']].head())
# Out:
# pandas.core.frame.DataFrame

# %%
#a data frame can hold multiple variables/columns
planes_df[['year', 'model']].head()
# Out:
#      year      model
# 0  2004.0  EMB-145XR
# 1  1998.0   A320-214
# 2  1999.0   A320-214
# 3  1999.0   A320-214
# 4  2002.0  EMB-145LR

# %%
#Slicing more about location and filtering is conditions

# %%
#slicing
#slicing, similar to row indexing, subsets cases by the value of the Index
#this is end inclusive, unlike indexing which is end exclusive
planes_df.loc[0:5]
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
# 5  N105UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan
# 5        2    182    NaN  Turbo-fan

# %%
#this is indexing, so it doesn't include row index 5
planes_df[0:5]
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 1  N102UW  1998.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 3  N104UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 1        2    182    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 3        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan

# %%
planes_df.loc[[0, 2 ,4, 6, 8]]
# Out:
#   tailnum    year                     type      manufacturer      model  \
# 0  N10156  2004.0  Fixed wing multi engine           EMBRAER  EMB-145XR
# 2  N103US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 4  N10575  2002.0  Fixed wing multi engine           EMBRAER  EMB-145LR
# 6  N107US  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
# 8  N109UW  1999.0  Fixed wing multi engine  AIRBUS INDUSTRIE   A320-214
#
#    engines  seats  speed     engine
# 0        2     55    NaN  Turbo-fan
# 2        2    182    NaN  Turbo-fan
# 4        2     55    NaN  Turbo-fan
# 6        2    182    NaN  Turbo-fan
# 8        2    182    NaN  Turbo-fan

# %%
#filtering
#filtering subsets cases using a conditional test
#this gets all manufacturers
planes_df['manufacturer']
# Out:
# 0                             EMBRAER
# 1                    AIRBUS INDUSTRIE
# 2                    AIRBUS INDUSTRIE
# 3                    AIRBUS INDUSTRIE
# 4                             EMBRAER
#                     ...
# 3317                           BOEING
# 3318    MCDONNELL DOUGLAS AIRCRAFT CO
# 3319                           BOEING
# 3320    MCDONNELL DOUGLAS CORPORATION
# 3321    MCDONNELL DOUGLAS CORPORATION
# Name: manufacturer, Length: 3322, dtype: object

# %%
#this gets all manufacturers
#this gets just where manufacturer = EMBRAER
planes_df['manufacturer'] == 'EMBRAER'
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 3317    False
# 3318    False
# 3319    False
# 3320    False
# 3321    False
# Name: manufacturer, Length: 3322, dtype: bool

# %%
planes_df[planes_df['manufacturer'] == 'EMBRAER'].head()
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 0   N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 4   N10575  2002.0  Fixed wing multi engine      EMBRAER  EMB-145LR        2
# 10  N11106  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 11  N11107  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 12  N11109  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#     seats  speed     engine
# 0      55    NaN  Turbo-fan
# 4      55    NaN  Turbo-fan
# 10     55    NaN  Turbo-fan
# 11     55    NaN  Turbo-fan
# 12     55    NaN  Turbo-fan

# %%
#build this so that the True values are the values we want
cond = planes_df['manufacturer'] == 'EMBRAER'
cond
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 3317    False
# 3318    False
# 3319    False
# 3320    False
# 3321    False
# Name: manufacturer, Length: 3322, dtype: bool

# %%
#only brings back the True values
planes_df[cond].head()
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 0   N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 4   N10575  2002.0  Fixed wing multi engine      EMBRAER  EMB-145LR        2
# 10  N11106  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 11  N11107  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 12  N11109  2002.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#     seats  speed     engine
# 0      55    NaN  Turbo-fan
# 4      55    NaN  Turbo-fan
# 10     55    NaN  Turbo-fan
# 11     55    NaN  Turbo-fan
# 12     55    NaN  Turbo-fan

# %%
planes_df.loc[planes_df['manufacturer']]

# %%
planes_df.loc[planes_df['year'] > 2002].head()
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 0   N10156  2004.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 15  N11121  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 16  N11127  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 17  N11137  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 18  N11140  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#     seats  speed     engine
# 0      55    NaN  Turbo-fan
# 15     55    NaN  Turbo-fan
# 16     55    NaN  Turbo-fan
# 17     55    NaN  Turbo-fan
# 18     55    NaN  Turbo-fan

# %%
planes_df.loc[(planes_df['year'] > 2002) & (planes_df['year'] < 2004)].head()
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 15  N11121  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 16  N11127  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 17  N11137  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 18  N11140  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 19  N11150  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#     seats  speed     engine
# 15     55    NaN  Turbo-fan
# 16     55    NaN  Turbo-fan
# 17     55    NaN  Turbo-fan
# 18     55    NaN  Turbo-fan
# 19     55    NaN  Turbo-fan

# %%
#combine the filter criteria in variables
cond_yr1 = planes_df['year'] > 2002
cond_yr2 = planes_df['year'] < 2004
cond_yr = cond_yr1 & cond_yr2
cond_yr #data
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3317    False
# 3318    False
# 3319    False
# 3320    False
# 3321    False
# Name: year, Length: 3322, dtype: bool

# %%
sum(cond_yr) #total True values
# Out:
# 150

# %%
planes_df.loc[cond_yr1 & cond_yr2].head()
# Out:
#    tailnum    year                     type manufacturer      model  engines  \
# 15  N11121  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 16  N11127  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 17  N11137  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 18  N11140  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
# 19  N11150  2003.0  Fixed wing multi engine      EMBRAER  EMB-145XR        2
#
#     seats  speed     engine
# 15     55    NaN  Turbo-fan
# 16     55    NaN  Turbo-fan
# 17     55    NaN  Turbo-fan
# 18     55    NaN  Turbo-fan
# 19     55    NaN  Turbo-fan

# %%
#find planes that have more than 3 engines
cond_engines = planes_df['engines'] > 3
cond_engines
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3317    False
# 3318    False
# 3319    False
# 3320    False
# 3321    False
# Name: engines, Length: 3322, dtype: bool

# %%
planes_df.loc[cond_engines].head()
# Out:
#      tailnum    year                     type      manufacturer     model  \
# 603   N281AT     NaN  Fixed wing multi engine  AIRBUS INDUSTRIE  A340-313
# 1037  N381AA  1956.0  Fixed wing multi engine           DOUGLAS    DC-7BF
# 2109  N670US  1990.0  Fixed wing multi engine            BOEING   747-451
# 2706  N840MQ  1974.0  Fixed wing multi engine      CANADAIR LTD     CF-5D
#
#       engines  seats  speed         engine
# 603         4    375    NaN      Turbo-jet
# 1037        4    102  232.0  Reciprocating
# 2109        4    450    NaN      Turbo-jet
# 2706        4      2    NaN      Turbo-jet

# %%
sum(cond_engines)
# Out:
# 4

# %%
sum(planes_df['engines'] > 3)
# Out:
# 4

# %%
#filtering and slicing together
planes_df_filtered = planes_df.loc[planes_df['manufacturer'] == 'EMBRAER']
planes_df_filtered_and_selected = planes_df_filtered[['year', 'engines']]
planes_df_filtered_and_selected.head()
# Out:
#       year  engines
# 0   2004.0        2
# 4   2002.0        2
# 10  2002.0        2
# 11  2002.0        2
# 12  2002.0        2

# %%
#or you can do slicing and filtering in a single line
planes_df.loc[planes_df['manufacturer'] == 'EMBRAER', ['year', 'engines']].head()
# Out:
#       year  engines
# 0   2004.0        2
# 4   2002.0        2
# 10  2002.0        2
# 11  2002.0        2
# 12  2002.0        2

# %%
#this is a nice clean approach
rows = planes_df['manufacturer'] == 'EMBRAER'
cols = ['year', 'engines']

# %%
planes_df.loc[rows, cols].head()
# Out:
#       year  engines
# 0   2004.0        2
# 4   2002.0        2
# 10  2002.0        2
# 11  2002.0        2
# 12  2002.0        2

# %%
#find entries from planes_df that have planes made by Boeing 
#and only seats and model variables
rows = planes_df['manufacturer'] == 'BOEING'
cols = ['seats', 'model']

# %%
planes_df.loc[rows, cols].head()
# Out:
#     seats    model
# 34    149  737-824
# 49    330  767-332
# 50    330  767-332
# 51    178  757-224
# 52    178  757-224
